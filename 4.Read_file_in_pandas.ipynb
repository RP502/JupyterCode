# %% [markdown]
# #### Import library pandas

# %%
import pandas as pd

# %% [markdown]
# ##### Read file csv

# %%
df_csv = pd.read_csv(r"C:\Users\dinhv\Downloads\csv files\titanic.csv")

# %%
df_csv
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### read full columns

# %%
pd.set_option('display.max.columns',16)

# %%
df_csv_2 = pd.read_csv(r"C:\Users\dinhv\Downloads\csv files\nigerian-songs.csv")

# %%
df_csv_2
# Out:
#                                                   name  \
# 0                                               Sparky
# 1                                           shuga rush
# 2                                                LITT!
# 3                             Confident / Feeling Cool
# 4                                           wanted you
# 5                                               Kasala
# 6                                              Pull Up
# 7                                         take a break
# 8                                                 Cash
# 9                                            SATISFIED
# 10                                             Morocco
# 11                                       luv in a mosh
# 12                                          Raw Dinner
# 13                                                Waka
# 14                        Summer Time (feat. Tay Iwar)
# 15                                       Bite the Dust
# ...

# %% [markdown]
# #### read full rows

# %%
pd.set_option('display.max.rows', 530)

# %% [markdown]
# ### Looking at data in Dataframe

# %%
df_csv_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              530 non-null    object
#  1   album             530 non-null    object
#  2   artist            530 non-null    object
#  3   artist_top_genre  530 non-null    object
#  4   release_date      530 non-null    int64
#  5   length            530 non-null    int64
#  6   popularity        530 non-null    int64
#  7   danceability      530 non-null    float64
#  8   acousticness      530 non-null    float64
#  9   energy            530 non-null    float64
#  10  instrumentalness  530 non-null    float64
#  11  liveness          530 non-null    float64
#  12  loudness          530 non-null    float64
#  13  speechiness       530 non-null    float64
#  14  tempo             530 non-null    float64
#  15  time_signature    530 non-null    int64
# ...

# %%
df_csv_2.shape
# Out:
# (530, 16)

# %%
df_csv_2.head()
# Out:
#                        name                         album  \
# 0                    Sparky            Mandy & The Jungle
# 1                shuga rush  EVERYTHING YOU HEARD IS TRUE
# 2                     LITT!                         LITT!
# 3  Confident / Feeling Cool               Enjoy Your Life
# 4                wanted you                         rare.
#
#                 artist artist_top_genre  release_date  length  popularity  \
# 0        Cruel Santino  alternative r&b          2019  144000          48
# 1  Odunsi (The Engine)          afropop          2020   89488          30
# 2                 AYLØ        indie r&b          2018  207758          40
# 3           Lady Donli     nigerian pop          2019  175135          14
# 4  Odunsi (The Engine)          afropop          2018  152049          25
#
#    danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0         0.666        0.8510   0.420          0.534000    0.1100    -6.699
# ...

# %%
df_csv_2.tail()
# Out:
#               name        album           artist artist_top_genre  \
# 525        Kwaroro      Kwaroro       J. Martins   afro dancehall
# 526  Concert Party  Afro Escape  Various Artists   afro dancehall
# 527           Loko   Applaudise           Iyanya   afro dancehall
# 528           Gift   Applaudise           Iyanya   afro dancehall
# 529         Macoma   Applaudise           Iyanya   afro dancehall
#
#      release_date  length  popularity  danceability  acousticness  energy  \
# 525          2015  193960          10         0.735         0.632   0.918
# 526          2015  252708           0         0.602         0.177   0.883
# 527          2015  223159           0         0.729         0.238   0.864
# 528          2015  278280           0         0.809         0.049   0.806
# 529          2015  213426           0         0.816         0.114   0.961
#
#      instrumentalness  liveness  loudness  speechiness    tempo  \
# ...

# %%
df_csv_2['album']
# Out:
# 0                                     Mandy & The Jungle
# 1                           EVERYTHING YOU HEARD IS TRUE
# 2                                                  LITT!
# 3                                        Enjoy Your Life
# 4                                                  rare.
# 5                                               Pioneers
# 6                                      Everything Pretty
# 7                                                  rare.
# 8                                        Enjoy Your Life
# 9                                                 GEMINI
# 10                                    Mandy & The Jungle
# 11                          EVERYTHING YOU HEARD IS TRUE
# 12                                    Mandy & The Jungle
# 13                                              Wildfire
# 14                                       Suzie's Funeral
# 15                                       Enjoy Your Life
# ...
